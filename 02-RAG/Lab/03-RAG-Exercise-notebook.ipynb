# %% [markdown]
# # Exercise: Data Retrieval and Extraction
#
# This notebook is designed for you to practice loading structured and unstructured data, and extracting information from files. Follow the instructions below and implement your solutions in new code cells.

# %% [markdown]
# ## Instructions
#
# 1. **Import Required Classes**
#    - Import `StructuredDataLoader` and `UnstructuredDataLoader` from the provided `util.py` file.
#
# 2. **Load Structured Data**
#    - Create an instance of `StructuredDataLoader`.
#    - Load the json file `google_search_results.json` and display the first few rows.
#
# 3. **Load Unstructured Data**
#    - Create an instance of `UnstructuredDataLoader` with a reasonable chunk size.
#    - Extract text from the PDF file `2404.10305v2.pdf`.
#    - Extract tables from the same PDF file.
#    - Look at the images extracted from the pdf.
#
# 4. **Explore and Analyze**
#    - Explore the loaded data and extracted text/tables.
#    - Summarize your findings or observations in markdown cells.
#
# ---
#
# Add your code and notes in new cells below each instruction. Good luck!
